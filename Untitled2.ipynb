# %% [markdown]
# <a href="https://colab.research.google.com/github/arbazkhan0786/CodeAlpha/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PySpark Program***

# %%
from pyspark import SparkContext

# %%
sc = SparkContext("local", "WordCount")

# %%
text_file = sc.textFile("input.txt")

# %%
with open('/content/input.txt', 'w') as f:
    f.write('This is a test file.\n')
    f.write('This file is for word count.\n')
    f.write('Test word count.')
print('input.txt created successfully.')
# Out:
# input.txt created successfully.

# %% [markdown]
# Now, let's re-run the Spark word count code and display the results.

# %%
text_file = sc.textFile("input.txt")

# %%
words = text_file.flatMap(lambda line: line.split(" "))
pairs = words.map(lambda word: (word, 1))
counts = pairs.reduceByKey(lambda a, b: a + b)

# %%
output = counts.collect()
for (word, count) in output:
    print("%s: %i" % (word, count))
# Out:
# This: 2
# is: 2
# a: 1
# test: 1
# file.: 1
# file: 1
# for: 1
# word: 2
# count.: 2
# Test: 1

# %%
sc.stop()

# %% [markdown]
# **Scala Spark Program**

# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setAppName("WordCount").setMaster("local")

# %%
sc = SparkContext(conf=conf)

# %%
textFile = sc.textFile("input.txt")

# %%
counts = textFile \
    .flatMap(lambda line: line.split(" ")) \
    .map(lambda word: (word, 1)) \
    .reduceByKey(lambda a, b: a + b)

# %%
for word, count in counts.collect():
    print(word, count)
# Out:
# This 2
# is 2
# a 1
# test 1
# file. 1
# file 1
# for 1
# word 2
# count. 2
# Test 1

# %%
sc.stop()
